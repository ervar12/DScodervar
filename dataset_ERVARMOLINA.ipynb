# %% [markdown]
# # Primer entrega

# %% [markdown]
# **Data** set 1 "Clientes del Banco"

# %% [markdown]
# Caracteristicas del data set: Muy interesante data set, pero por lo observado en el sitio Kaggle.com donde se obtuvo, se visualizan trabajos ya hechos de prediccion y ML. Por lo que seria la ultima opcion a elegir de los tres que se presentan.

# %%
import pandas as pd
df1= pd.read_csv('/content/drive/MyDrive/Data Science/Data sets/Bank Customer Churn Prediction.csv')
print(f'Dimension : {df1.shape}')
df1.head(5)
# Out:
# Dimension : (10000, 12)
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# ** Data set 2 " Enfermedaes y plagas en Arroz"**

# %% [markdown]
# Caracteristicas del data set:  A priori muy intersante sobre todo para sentar precedente para utilizar como modelo para cultivos tradicionales de la Argentina en donde la siembra directa y su utilizacion intensiva de insumos podria ser de mayor utilidad.
# En India, de donde son originarios los datos, una agricultura todavia con tecnologia tradicional servira de base para estimar costos de aplicaciones, umbrales de daño y accion, estadios de plaga o enfermadad para apliciones, entre otros ( a medida que releve mas informacion sobre el contexto del arroz en India podre detallar mas y lograr hipotesis interesantes para contrastar con los datos y hacer de estos un conjunto de informacion util).
# Desde el punto de vista comercial, claramente no es facil obtener insight o patrones confiables en el ambito biologico , pero utilizando parametros ambientales y especies involucradas, planteo la hipotesis de que existen aceptables posiblidades de generar un modelo predictivo para generar intervalos de confianza para ayudar en la toma de decision sobre cuando y como aplicar productos fitosanitarios desde el punto de vista de la sanidad vegetal, y tambien la misma hipotesis desde la perspectiva de si es economicamente rentable.
# Posibles Variables interesantes ex-ante :
#
#
# *   Pest value, Collection type, MaxT ,MinT, RH1, RF,SSH

# %%
df2= pd.read_csv('/content/drive/MyDrive/Data Science/Data sets/RICE.csv')

print(f'Dimension : {df2.shape}')
df2.head(5)
# Out:
# Dimension : (19404, 14)
#    Observation Year  Standard Week  Pest Value Collection Type  MaxT  MinT  \
# 0              2003              1         0.0     Number/hill  27.9  14.8
# 1              2003              2         0.0     Number/hill  27.2  15.0
# 2              2003              3         0.0     Number/hill  28.7  18.3
# 3              2003              4         0.0     Number/hill  25.3  16.4
# 4              2003              5         0.0     Number/hill  28.8  18.7
#
#    RH1(%)  RH2(%)  RF(mm)  WS(kmph)  SSH(hrs)  EVP(mm)         PEST NAME  \
# 0    94.7    51.3     0.0       3.1       8.7      2.7  Brownplanthopper
# 1    93.9    53.1     0.0       2.1       8.7      2.4  Brownplanthopper
# 2    94.1    56.7     0.6       4.8       6.7      2.8  Brownplanthopper
# 3    90.9    57.4     0.3       6.5       5.3      3.0  Brownplanthopper
# 4    95.7    55.0     0.0       5.2       6.3      2.8  Brownplanthopper
#
#   Location
# 0  Cuttack
# 1  Cuttack
# 2  Cuttack
# ...

# %% [markdown]
# Data set 2 "Empleo y salario como Data Science"

# %% [markdown]
# Caracteristicas del data set: Relacionado con el curso del cual se deriva este proyecto.
# Desde la mirada del auge de la Revolucion 4.0 , el IOT y todo lo que respecta al mundo de los datos, son estos empleos bien remunerados en relacion a los beneficios directos e indirectos que generan? Mantendran alguna tendencia predecible los salarios medidos en dolares? Depende del tamaño de la empresa o influye en mayor medida donde esta localizada la empresa?
# Bueno son algunas preguntas como para empezar a diagramar las relaciones entre las variables y que otra informacion se podra extraer de los datos obtenidos en este data set.
# Variables candidatas :
#
#
# *   Salary_in_usd, company_size, company_location

# %%
df3= pd.read_csv('/content/drive/MyDrive/Data Science/Data sets/jobs_in_data.csv')

print(f'Dimension : {df3.shape}')
df3.head(5)
# Out:
# Dimension : (9355, 12)
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df2.info()
#cero nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19404 entries, 0 to 19403
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Observation Year  19404 non-null  int64
#  1   Standard Week     19404 non-null  int64
#  2   Pest Value        19404 non-null  float64
#  3   Collection Type   19404 non-null  object
#  4   MaxT              19404 non-null  float64
#  5   MinT              19404 non-null  float64
#  6   RH1(%)            19404 non-null  float64
#  7   RH2(%)            19404 non-null  float64
#  8   RF(mm)            19404 non-null  float64
#  9   WS(kmph)          19404 non-null  float64
#  10  SSH(hrs)          19404 non-null  float64
#  11  EVP(mm)           19404 non-null  float64
#  12  PEST NAME         19404 non-null  object
#  13  Location          19404 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
df2.describe()
# Out:
#        Observation Year  Standard Week     Pest Value          MaxT  \
# count      19404.000000   19404.000000   19404.000000  19404.000000
# mean        2000.024789      26.473717     807.944081     31.169006
# std            9.827306      15.016247    5290.180315      4.904610
# min         1959.000000       1.000000       0.000000     10.900000
# 25%         1996.000000      13.000000       0.000000     28.800000
# 50%         2001.000000      26.000000       3.000000     30.900000
# 75%         2007.000000      39.000000      92.000000     33.425000
# max         2011.000000      52.000000  311169.000000     71.600000
#
#                MinT        RH1(%)        RH2(%)        RF(mm)      WS(kmph)  \
# count  19404.000000  19404.000000  19404.000000  19404.000000  19404.000000
# mean      20.404540     82.190981     53.725763     19.414152      4.501268
# std        5.388381     13.846883     18.948801     39.160009      3.194973
# ...

# %%
"""por lo que estuve investigando este data set lo hizo un estudiante indio que obtuvo los datos de la pagina de una empresa agroquimica, pero todavia no pude decifrar que parametros o cuales son las variables involucradas para
darle valor o determinada puntuacion a Pest Value"""
# Out:
# 'por lo que estuve investigando este data set lo hizo un estudiante indio que obtuvo los datos de la pagina de una empresa agroquimica, pero todavia no pude decifrar que parametros o cuales son las variables involucradas para\ndarle valor o determinada puntuacion a Pest Value'

# %%
#contar nulos
nun_missing= (df2[['Observation Year','Standard Week', 'Pest Value', 'MaxT'	, 'MinT',	'RH1(%)',	'RH2(%)',	'RF(mm)',	'WS(kmph)',	'SSH(hrs)','EVP(mm)']] ==0).sum()
print (nun_missing)
# Out:
# Observation Year       0
# Standard Week          0
# Pest Value          8670
# MaxT                   0
# MinT                   0
# RH1(%)                 0
# RH2(%)                 0
# RF(mm)              9869
# WS(kmph)             988
# SSH(hrs)             279
# EVP(mm)             1004
# dtype: int64
